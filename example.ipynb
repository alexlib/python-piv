# %%
from piv import PivImage

# %%
image_of_interest = PivImage(image_path='test_images/phi90074A.tif', run_id='test')
image_of_interest.plot_results()

# %%
USEFUL_PIV_ATTRIBUTES = ['run_id','flame_min_x','flame_min_y',
                         'flame_centerline_x','flame_centerline_y',
                         'flags']

{attribute:image_of_interest.__dict__[attribute] 
 for attribute in USEFUL_PIV_ATTRIBUTES}
# Out:
# {'run_id': 'test',
#  'flame_min_x': 1191,
#  'flame_min_y': 412,
#  'flame_centerline_x': 1024,
#  'flame_centerline_y': 539,
#  'flags': []}
